# %%
import pandas as pd
import numpy as np

# %%
# %%time

data = pd.read_csv("hyderabad.csv")
data.shape
# Out:
# Wall time: 542 ms
# <decorator-gen-55>:2: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
# (18900, 35)

# %%
data.head()
# Out:
#    active                                          amenities balconies  \
# 0    True  {"LIFT":true,"GYM":false,"INTERNET":true,"AC":...         2
# 1    True  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...         1
# 2    True  {"LIFT":true,"GYM":false,"INTERNET":true,"AC":...         2
# 3    True  {"LIFT":true,"GYM":false,"INTERNET":true,"AC":...         1
# 4    True  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...         1
#
#    bathroom  combineDescription  \
# 0         2                 NaN
# 1         3                 NaN
# 2         2                 NaN
# 3         2                 NaN
# 4         2                 NaN
#
#                                   completeStreetName deposit facing  \
# 0            Ramakrishna Nagar, near Reliance Trends   30000      W
# 1  Hilltop Colony, Padmavathi Nagar, Khairatabad,...   90000      S
# 2         Phase 1 , near Srikara Hospitals - Miyapur   50000      N
# ...

# %%
data.isnull().sum()
# Out:
# active                    0
# amenities                 0
# balconies                 0
# bathroom                  0
# combineDescription    18900
# completeStreetName        2
# deposit                   0
# facing                    0
# facingDesc             9431
# floor                     0
# furnishingDesc            1
# gym                       0
# id                        0
# isMaintenance             0
# lift                      0
# loanAvailable             0
# locality                  2
# localityId                0
# location                  0
# maintenanceAmount         0
# ownerName                 0
# parking                   0
# parkingDesc               1
# propertyTitle             0
# propertyType              0
# property_age              0
# reactivationSource       73
# rent_amount               0
# sharedAccomodation        0
# shortUrl                  0
# swimmingPool              0
# totalFloor                0
# type_bhk                  0
# ...

# %%
data.drop(['weight','combineDescription'],axis=1,inplace=True)

# %%
data.to_csv("hyd.csv")
